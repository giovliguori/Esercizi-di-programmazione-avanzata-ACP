# %%
#########################
## EXAMPLE: returning a tuple
#########################
def quotient_and_remainder(x, y):
    q = x // y
    r = x % y
    return (q, r)
    
(quot, rem) = quotient_and_remainder(5,2)
print(quot)
print(rem)

# %%
#########################
## EXAMPLE: iterating over tuples
#########################
def get_data(aTuple):
    """
    aTuple, tuple di tuples (int, string)
    Estrae tutti gli interi da aTuple e li setta
    come elementi in una nuova tupla. 
    Estrae tutte le stringhe uniche da aTuple e le setta
    come elementi in una nuova tupla.
    Ritorna la tuple del minimo e del massimo nella tupla di interi,
    e il numero di stringhe unique.
    """
    nums = ()    # empty tuple
    words = ()
    for t in aTuple:
        #print("curren t: " + str(t))
        # concatenating with a singleton tuple, t[0] è il primo el della tupla, gli interi
        nums = nums + (t[0],)   
        # only add words haven't added before,  t[1] è il secondo el della tupla, le stringhe
        if t[1] not in words:   
            words = words + (t[1],)
    min_n = min(nums)
    max_n = max(nums)
    unique_words = len(words)
    return (min_n, max_n, unique_words)

test = ((1,"a"),(2, "b"),
        (1,"a"),(7,"b"))
(a, b, c) = get_data(test)
print("a:",a,"b:",b,"c:",c)

# apply to any data you want!
tswift = ((2014,"Katy"),
          (2014,"Harry"),
          (2012,"Jake"), 
          (2010,"Taylor"), 
          (2008,"Joe"))    
(min_year, max_year, num_people) = get_data(tswift)
print("From", min_year, "to", max_year, \
        "Taylor Swift wrote songs about", num_people, "people!")

# %%
a_list = []
L = [2, 'a', 4, [1,2]]
print("len(L) " + str(len(L)))
print(L[0])
print(L[2]+1)
print(L[3])
#L[4]
i = 2
print(L[i-1])

# %%
#########################
## EXAMPLE: sum of elements in a list
#########################
def sum_elem_method1(L):
  total = 0 
  for i in range(len(L)): 
      total += L[i] 
  return total
  
def sum_elem_method2(L):
    total = 0 
    for i in L: 
        total += i 
    return total
  
print(sum_elem_method1([1,2,3,4]))
print(sum_elem_method2([1,2,3,4]))

# %%
#########################
## EXAMPLE: various list operations
## put print(L) at different locations to see how it gets mutated
#########################
L1 = [2,1,3]
L2 = [4,5,6]
print("concateno L1 e L2")
L3 = L1 + L2
print(L3)
print(L1)
print("concateno L1 con la lista [0,6]")
L1.extend([0,6])
print(L1)

#Operazioni di rimozione da una lista
L = [2,1,3,6,3,7,0]
L.remove(2)
L.remove(3)
del(L[1])
print(L.pop())

#Converto stringa in lista e opero con split e join
s = "I<3 cs"
print(list(s))
print(s.split('<'))
L = ['a', 'b', 'c']
print(''.join(L))
print('_'.join(L))

# operazioni di ordinamento su liste
L=[9,6,0,3]
print(sorted(L))
L.sort()
L.reverse()

# %%
#########################
## EXAMPLE: aliasing
#########################
a = 1
b = a
print(a)
print(b)

warm = ['red', 'yellow', 'orange']


res = sorted(warm)
print(res)
print(warm)

# %%
#########################
## EXAMPLE: cloning
#########################
cool = ['blue', 'green', 'grey']
chill = cool[:]
chill.append('black')
print(chill)
print(cool)

# %%
#########################
## EXAMPLE: sorting with/without mutation
#########################
warm = ['red', 'yellow', 'orange']
sortedwarm = warm.sort()
print(warm)
print(sortedwarm)

cool = ['grey', 'green', 'blue']
sortedcool = sorted(cool)
print(cool)
print(sortedcool)

# %%
#########################
## EXAMPLE: lists of lists of lists...
#########################
warm = ['yellow', 'orange']
hot = ['red']
brightcolors = [warm]
brightcolors.append(hot)
print(brightcolors)
hot.append('pink')
print(hot)
print(brightcolors)

# %%
###############################
## EXAMPLE: mutating a list while iterating over it
###############################
def remove_dups(L1, L2):
    for e in L1:
        if e in L2:
            L1.remove(e)
      
def remove_dups_new(L1, L2):
    L1_copy = L1[:]
    for e in L1_copy:
        if e in L2:
            L1.remove(e)

L1 = [1, 2, 3, 4]
L2 = [1, 2, 5, 6]
print(L1)
print(L2)
remove_dups(L1, L2)
print("after remove_dups")
print(L1, L2)

L1 = [1, 2, 3, 4]
L2 = [1, 2, 5, 6]
remove_dups_new(L1, L2)
print("after remove_dups_new")
print(L1, L2)

# %%
###############################
## EXERCISE: Test yourself by predicting what the output is and 
##           what gets mutated then check with the Python Tutor
###############################
cool = ['blue', 'green']
warm = ['red', 'yellow', 'orange']
print(cool)
print(warm)

colors1 = [cool]
print(colors1)
colors1.append(warm)
print('colors1 = ', colors1)

colors2 = [['blue', 'green'],
          ['red', 'yellow', 'orange']]
print('colors2 =', colors2)

warm.remove('red') 
print('colors1 = ', colors1)
print('colors2 =', colors2)

for e in colors1:
    print('e =', e)

for e in colors1:
    if type(e) == list:
        for e1 in e:
            print(e1)
    else:
        print(e)

flat = cool + warm
print('flat =', flat)

print(flat.sort())
print('flat =', flat)

new_flat = sorted(flat, reverse = True)
print('flat =', flat)
print('new_flat =', new_flat)

cool[1] = 'black'
print(cool)
print(colors1)

# %%
my_dict = {}

grades = {'Ana':'B', 'John':'A+', 'Denise':'A', 'Katy':'A'}

grades['John']
#grades['Sylvan'] # da errore perchè
grades['Sylvan'] = 'A'

if 'John' in grades:
    print("YEEEEEEEEE")

del(grades['Ana'])

print(grades.keys())

print(grades.values())

for key, values in grades.items():
    print(key)
    print(values)

# %%
#####################################
# EXAMPLE: using dictionaries
#          counting frequencies of words in song lyrics
#####################################

"""
Obiettivo: dal testo di una canzone messo come lista voglio
ottenere una lista di tuple. Ogni tupla è una contiene
come primo elemento una lista di parole della canzone, mentre
il secondo argomento indica la frequenza della lista di parole

[(['you'], 36), 
    (['yeah'], 28), 
    (['she'], 20), 
    (['loves'], 13), 
    (['know'], 11), 
    (['be'], 10), 
    (['and'], 8), 
    (['that', 'should', 'glad'], 7), 
    (['love'], 5)]

"""

def lyrics_to_frequencies(lyrics):
    """
        creo un dictionaty con chiave pari alla parola
        nel testo della canzone (lyrics) e valore frequenza
    """
    myDict = {}
    for word in lyrics:
        if word in myDict:
            myDict[word] += 1
        else:
            myDict[word] = 1
    return myDict
    
    
she_loves_you = ['she', 'loves', 'you', 'yeah', 'yeah', 
'yeah','she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',

'you', 'think', "you've", 'lost', 'your', 'love',
'well', 'i', 'saw', 'her', 'yesterday-yi-yay',
"it's", 'you', "she's", 'thinking', 'of',
'and', 'she', 'told', 'me', 'what', 'to', 'say-yi-yay',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'she', 'said', 'you', 'hurt', 'her', 'so',
'she', 'almost', 'lost', 'her', 'mind',
'and', 'now', 'she', 'says', 'she', 'knows',
"you're", 'not', 'the', 'hurting', 'kind',

'she', 'says', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',

'you', 'know', "it's", 'up', 'to', 'you',
'i', 'think', "it's", 'only', 'fair',
'pride', 'can', 'hurt', 'you', 'too',
'pologize', 'to', 'her',

'Because', 'she', 'loves', 'you',
'and', 'you', 'know', 'that', "can't", 'be', 'bad',
'Yes', 'she', 'loves', 'you',
'and', 'you', 'know', 'you', 'should', 'be', 'glad',

'oo', 'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'she', 'loves', 'you', 'yeah', 'yeah', 'yeah',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'with', 'a', 'love', 'like', 'that',
'you', 'know', 'you', 'should', 'be', 'glad',
'yeah', 'yeah', 'yeah',
'yeah', 'yeah', 'yeah', 'yeah'
]

beatles = lyrics_to_frequencies(she_loves_you)

print("lyrics")
print(beatles)

def most_common_words(freqs):
    values = freqs.values() # ottengo la lista di values a partire dal dict freqs
    best = max(freqs.values()) # ottengo il max tra la lista di values
    words = []
    for k in freqs: # itero su tutti i valori del dict, prendendo solo le chiavi del dict
        if freqs[k] == best: # se l'elemento corrente con chiave k coincide con 
                             # il max aggiungo la chiave dell'el del dict alla lista words
            words.append(k)
            
    return (words, best) # ritorna una tupla con la lista di parole (primo el) e freq. (secondo el)
                         # e.g., (['she', 'you'], 10)
    
    
    
def words_often(freqs, minTimes):
    
    """
        Prende in ingresso un dict (freqs) con ['word' : frequency]
        e ritorna una lista (result) che è una lista di tuple. 
        Ogni tupla è una contiene come primo elemento una lista di parole della canzone, mentre
        il secondo argomento indica la frequenza della lista di parole
        L'arg minTimes specifica la freq minima per cui voglio ottenere la lista di parole
        della mia canzone
    """
    
    result = []
    done = False
    while not done and len(freqs) > 0:
        temp = most_common_words(freqs) # temp = (['she', 'you'], 10)
        if temp[1] >= minTimes:
            result.append(temp)
            for w in temp[0]:
                del(freqs[w])  #remove word from dict
        else: # se la lista di parole corrente non ha freq minima minTimes ho finito, perchè la chiamata
                # a most_common_words mi ordina anche la lista di tuple per freq.
                
            done = True
    return result

print("\n")
print(words_often(beatles, 5))
# Out:
# lyrics
# {'she': 20, 'loves': 13, 'you': 36, 'yeah': 28, 'think': 2, "you've": 1, 'lost': 2, 'your': 1, 'love': 5, 'well': 1, 'i': 2, 'saw': 1, 'her': 4, 'yesterday-yi-yay': 1, "it's": 3, "she's": 1, 'thinking': 1, 'of': 1, 'and': 8, 'told': 1, 'me': 1, 'what': 1, 'to': 3, 'say-yi-yay': 1, 'says': 3, 'know': 11, 'that': 7, "can't": 3, 'be': 10, 'bad': 3, 'yes': 2, 'should': 7, 'glad': 7, 'said': 1, 'hurt': 2, 'so': 1, 'almost': 1, 'mind': 1, 'now': 1, 'knows': 1, "you're": 1, 'not': 1, 'the': 1, 'hurting': 1, 'kind': 1, 'oo': 2, 'with': 4, 'a': 4, 'like': 4, 'up': 1, 'only': 1, 'fair': 1, 'pride': 1, 'can': 1, 'too': 1, 'pologize': 1, 'Because': 1, 'Yes': 1}
#
#
# [(['you'], 36), (['yeah'], 28), (['she'], 20), (['loves'], 13), (['know'], 11), (['be'], 10), (['and'], 8), (['that', 'should', 'glad'], 7), (['love'], 5), (['her', 'with', 'a', 'like'], 4), (["it's", 'to', 'says', "can't", 'bad'], 3), (['think', 'lost', 'i', 'yes', 'hurt', 'oo'], 2), (["you've", 'your', 'well', 'saw', 'yesterday-yi-yay', "she's", 'thinking', 'of', 'told', 'me', 'what', 'say-yi-yay', 'said', 'so', 'almost', 'mind', 'now', 'knows', "you're", 'not', 'the', 'hurting', 'kind', 'up', 'only', 'fair', 'pride', 'can', 'too', 'pologize', 'Because', 'Yes'], 1)]
