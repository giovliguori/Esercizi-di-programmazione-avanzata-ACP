# %%
import requests

def print_response(response):

    print("Encoding:", response.encoding)
    print("Status code:", response.status_code)
    print("URL:", response.url)
    print("Server Header:", response.headers['Server'])
    print("Headers:", response.headers)
    print("Content:", response.content)
    print("Text", response.text)
    
    try:
        print("JSON:", response.json())
        #response.json()[0]['pippo']
    except requests.exceptions.JSONDecodeError:
        print("Response not in JSON format")

    print()

# HEAD
print('## HEAD ##')
resp = requests.head('https://httpbin.org/get')
print_response(resp)

# GET
print('## GET ##')
resp = requests.get('https://httpbin.org/get')
print_response(resp)

# POST
print('## POST ##')
resp = requests.post('https://httpbin.org/post', data={'key': 'value'})
print_response(resp)

# PUT
print('## PUT ##')
resp = requests.put('https://httpbin.org/put')
print_response(resp)

# DELETE
print('## DELETE ##')
resp = requests.delete('https://httpbin.org/delete')
print_response(resp)
# Out:
# ## HEAD ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Thu, 07 May 2026 13:47:30 GMT', 'Content-Type': 'application/json', 'Content-Length': '307', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b''
# Text
# Response not in JSON format
#
# ## GET ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Thu, 07 May 2026 13:47:30 GMT', 'Content-Type': 'application/json', 'Content-Length': '307', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-69fc97f2-712b877b2dfeb1890eb9a05d"\n  }, \n  "origin": "143.225.7.135", \n  "url": "https://httpbin.org/get"\n}\n'
# Text {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-69fc97f2-712b877b2dfeb1890eb9a05d"
#   },
#   "origin": "143.225.7.135",
#   "url": "https://httpbin.org/get"
# }
#
# JSON: {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-69fc97f2-712b877b2dfeb1890eb9a05d'}, 'origin': '143.225.7.135', 'url': 'https://httpbin.org/get'}
#
# ## POST ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/post
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Thu, 07 May 2026 13:47:31 GMT', 'Content-Type': 'application/json', 'Content-Length': '479', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-69fc97f3-76a2591705bcc8f800096c9f"\n  }, \n  "json": null, \n  "origin": "143.225.7.135", \n  "url": "https://httpbin.org/post"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-69fc97f3-76a2591705bcc8f800096c9f"
#   },
#   "json": null,
#   "origin": "143.225.7.135",
#   "url": "https://httpbin.org/post"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {'key': 'value'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '9', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-69fc97f3-76a2591705bcc8f800096c9f'}, 'json': None, 'origin': '143.225.7.135', 'url': 'https://httpbin.org/post'}
#
# ## PUT ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/put
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Thu, 07 May 2026 13:47:31 GMT', 'Content-Type': 'application/json', 'Content-Length': '398', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-69fc97f3-40fe37b53674a7f96dbec89f"\n  }, \n  "json": null, \n  "origin": "143.225.7.135", \n  "url": "https://httpbin.org/put"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-69fc97f3-40fe37b53674a7f96dbec89f"
#   },
#   "json": null,
#   "origin": "143.225.7.135",
#   "url": "https://httpbin.org/put"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '0', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-69fc97f3-40fe37b53674a7f96dbec89f'}, 'json': None, 'origin': '143.225.7.135', 'url': 'https://httpbin.org/put'}
#
# ## DELETE ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/delete
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Thu, 07 May 2026 13:47:32 GMT', 'Content-Type': 'application/json', 'Content-Length': '401', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-69fc97f4-259e2f680e956d080d1a440b"\n  }, \n  "json": null, \n  "origin": "143.225.7.135", \n  "url": "https://httpbin.org/delete"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-69fc97f4-259e2f680e956d080d1a440b"
#   },
#   "json": null,
#   "origin": "143.225.7.135",
#   "url": "https://httpbin.org/delete"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '0', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-69fc97f4-259e2f680e956d080d1a440b'}, 'json': None, 'origin': '143.225.7.135', 'url': 'https://httpbin.org/delete'}

# %%
import requests

# GET
print('## GET ##')
resp = requests.get('http://127.0.0.1:5000/users')
print_response(resp)

# %%
# GET with query string
print('## GET - 1 ##')
payload = {'key1': 'value1', 'key2': 'value2'}
resp = requests.get('https://httpbin.org/get', params=payload)
print_response(resp)

# GET with query string (multiple values for a key)
print('## GET - 2 ##')
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
resp = requests.get('https://httpbin.org/get', params=payload)
print_response(resp)

# %%
# POST with multiple keys
print('## POST - 1 ##')
payload = {'key1': 'value1', 'key2': 'value2'}
resp = requests.post('https://httpbin.org/post', data=payload)
print_response(resp)

# POST with multiple values for a key
print('## POST - 2 ##')
payload_dict = {'key1': ['value1', 'value2']}
resp = requests.post('https://httpbin.org/post', data=payload_dict)
print_response(resp)

# %%
import requests

def print_response(response):

    print("Encoding:", response.encoding)
    print("Status code:", response.status_code)
    print("URL:", response.url)
    print("Server Header:", response.headers['Server'])
    print("Headers:", response.headers)
    print("Content:", response.content)
    print("Text", response.text)
    
    try:
        print("JSON:", response.json())
    except requests.exceptions.JSONDecodeError:
        print("Response not in JSON format")

    print()

# Generate a bad response
resp = requests.get('https://httpbin.org/status/404')
print_response(resp)

# Check for error
resp.raise_for_status()
